# %% [markdown]
# # Assignment #8

# %%
import pandas as pd
import dash
import dash_cytoscape as cyto
from dash import html, dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
from jupyter_dash.comms import _send_jupyter_config_comm_request

# %%
_send_jupyter_config_comm_request()

# %%
JupyterDash.infer_jupyter_proxy_config()

# %%
import requests

# %%
response = requests.get("https://www.gutenberg.org/cache/epub/1524/pg1524.txt")

# %%
from bs4 import BeautifulSoup

# %%
html_string = response.text
document = BeautifulSoup(html_string, "html.parser")

# %%
x = document

# %%
x
# Out:
# ﻿The Project Gutenberg eBook of Hamlet, by William Shakespeare
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org. If you are not located in the United States, you
# will have to check the laws of the country where you are located before
# using this eBook.
#
# Title: Hamlet
#
# Author: William Shakespeare
#
# Release Date: November 1998 [eBook #1524]
# [Most recently updated: October 17, 2021]
#
# Language: English
#
#
# Produced by: Dianne Bean
#
# *** START OF THE PROJECT GUTENBERG EBOOK HAMLET ***
#
#
#
#
# THE TRAGEDY OF HAMLET, PRINCE OF DENMARK
#
# by William Shakespeare
#
#
# Contents
#
# ACT I
# Scene I. Elsinore. A platform before the Castle.
# Scene II. Elsinore. A room of state in the Castle
# ...

# %%
type(x)
# Out:
# bs4.BeautifulSoup

# %%
x_string = str(x)

# %%
type(x_string)
# Out:
# str

# %%
x_string
# Out:
# '\ufeffThe Project Gutenberg eBook of Hamlet, by William Shakespeare\r\n\r\nThis eBook is for the use of anyone anywhere in the United States and\r\nmost other parts of the world at no cost and with almost no restrictions\r\nwhatsoever. You may copy it, give it away or re-use it under the terms\r\nof the Project Gutenberg License included with this eBook or online at\r\nwww.gutenberg.org. If you are not located in the United States, you\r\nwill have to check the laws of the country where you are located before\r\nusing this eBook.\r\n\r\nTitle: Hamlet\r\n\r\nAuthor: William Shakespeare\r\n\r\nRelease Date: November 1998 [eBook #1524]\r\n[Most recently updated: October 17, 2021]\r\n\r\nLanguage: English\r\n\r\n\r\nProduced by: Dianne Bean\r\n\r\n*** START OF THE PROJECT GUTENBERG EBOOK HAMLET ***\r\n\r\n\r\n\r\n\r\nTHE TRAGEDY OF HAMLET, PRINCE OF DENMARK\r\n\r\nby William Shakespeare\r\n\r\n\r\nContents\r\n\r\nACT I\r\nScene I. Elsinore. A platform before the Castle.\r\nScene II. Els
# ...

# %%
x_string.split('Act')[1].split('SCENE')[1]
# Out:
# ' VI. Another room in the Castle.\r\n\r\n Enter Horatio and a Servant.\r\n\r\nHORATIO. What are they that would speak with me?\r\n\r\nSERVANT. Sailors, sir. They say they have letters for you.\r\n\r\nHORATIO. Let them come in.\r\n\r\n [_Exit Servant._]\r\n\r\nI do not know from what part of the world I should be greeted, if not\r\nfrom Lord Hamlet.\r\n\r\n Enter Sailors.\r\n\r\nFIRST SAILOR. God bless you, sir.\r\n\r\nHORATIO. Let him bless thee too.\r\n\r\nFIRST SAILOR. He shall, sir, and’t please him. There’s a letter for\r\nyou, sir. It comes from th’ambassador that was bound for England; if\r\nyour name be Horatio, as I am let to know it is.\r\n\r\nHORATIO. [_Reads._] ‘Horatio, when thou shalt have overlooked this,\r\ngive these fellows some means to the King. They have letters for him.\r\nEre we were two days old at sea, a pirate of very warlike appointment\r\ngave us chase. Finding ourselves too slow of sail, we put on a\r\ncompelled valour, and in the grapple I boarded them. O
# ...

# %%
acts = x_string.split('ACT')[5:]
#this splits up the acts into 5 different categories because there are only 5 acts in this play.

# %%
acts[1]
#this splits the acts up into categories.
# Out:
# ' I\r\n\r\nSCENE I. Elsinore. A platform before the Castle.\r\n\r\n Enter Francisco and Barnardo, two sentinels.\r\n\r\nBARNARDO. Who’s there?\r\n\r\nFRANCISCO. Nay, answer me. Stand and unfold yourself.\r\n\r\nBARNARDO. Long live the King!\r\n\r\nFRANCISCO. Barnardo?\r\n\r\nBARNARDO. He.\r\n\r\nFRANCISCO. You come most carefully upon your hour.\r\n\r\nBARNARDO. ’Tis now struck twelve. Get thee to bed, Francisco.\r\n\r\nFRANCISCO. For this relief much thanks. ’Tis bitter cold, And I am sick\r\nat heart.\r\n\r\nBARNARDO. Have you had quiet guard?\r\n\r\nFRANCISCO. Not a mouse stirring.\r\n\r\nBARNARDO. Well, good night. If you do meet Horatio and Marcellus, The\r\nrivals of my watch, bid them make haste.\r\n\r\n Enter Horatio and Marcellus.\r\n\r\nFRANCISCO. I think I hear them. Stand, ho! Who is there?\r\n\r\nHORATIO. Friends to this ground.\r\n\r\nMARCELLUS. And liegemen to the Dane.\r\n\r\nFRANCISCO. Give you good night.\r\n\r\nMARCELLUS. O, farewell, honest soldier, who hath relie
# ...

# %%
acts[2]
#just checking the split up acts.
# Out:
# ' II\r\n\r\nSCENE I. A room in Polonius’s house.\r\n\r\n Enter Polonius and Reynaldo.\r\n\r\nPOLONIUS. Give him this money and these notes, Reynaldo.\r\n\r\nREYNALDO. I will, my lord.\r\n\r\nPOLONIUS. You shall do marvellous wisely, good Reynaldo, Before you\r\nvisit him, to make inquiry Of his behaviour.\r\n\r\nREYNALDO. My lord, I did intend it.\r\n\r\nPOLONIUS. Marry, well said; very well said. Look you, sir, Enquire me\r\nfirst what Danskers are in Paris; And how, and who, what means, and\r\nwhere they keep, What company, at what expense; and finding By this\r\nencompassment and drift of question, That they do know my son, come you\r\nmore nearer Than your particular demands will touch it. Take you as\r\n’twere some distant knowledge of him, As thus, ‘I know his father and\r\nhis friends, And in part him’—do you mark this, Reynaldo?\r\n\r\nREYNALDO. Ay, very well, my lord.\r\n\r\nPOLONIUS. ‘And in part him, but,’ you may say, ‘not well; But if’t be\r\nhe I mean, he’s very wild; A
# ...

# %%
acts[1].split('SCENE')[-1].find('HAMLET')
# Out:
# 69

# %%
characters = [
    'HAMLET',
    'CLAUDIUS', 
    'The GHOST'
    'GERTRUDE', 
    'POLONIUS',
    'LAERTES', 
    'OPHELIA', 
    'HORATIO', 
    'FORTINBRAS',
    'VOLTEMAND', 
    'CORNELIUS', 
    'ROSENCRANTZ', 
    'GUILDENSTERN',
    'MARCELLUS',
    'BARNARDO', 
    'FRANCISCO',
    'OSRIC',
    'REYNALDO',
    'Players',
    'A Gentleman',
    'A Priest',
    'Two Clowns',
    'A Captain',
    'English Ambassadors',
    'Lords, Ladies, Officers, Soldiers, Sailors, Messengers, and Attendants',
]

# %%
len(acts)
# Out:
# 8

# %%
charnum = {}

connections = {}
for i in range(len(characters)-1):
    for j in range(i+1,len(characters)):
        connections[(characters[i],characters[j])] = 0

for k in characters:
    charnum[k] = 0

for i in acts:
    for j in i.split('SCENE')[1:]:
        scenechars = []
        for k in characters:
            if j.find(k) != -1:
                scenechars.append(k)
                charnum[k] += 1
        for a in range(len(scenechars)-1):
            for b in range(a+1,len(scenechars)):
                connections[(scenechars[a],scenechars[b])] += 1

# %%
charnum
# Out:
# {'HAMLET': 15,
#  'CLAUDIUS': 0,
#  'The GHOSTGERTRUDE': 0,
#  'POLONIUS': 8,
#  'LAERTES': 6,
#  'OPHELIA': 5,
#  'HORATIO': 8,
#  'FORTINBRAS': 2,
#  'VOLTEMAND': 2,
#  'CORNELIUS': 1,
#  'ROSENCRANTZ': 7,
#  'GUILDENSTERN': 5,
#  'MARCELLUS': 4,
#  'BARNARDO': 2,
#  'FRANCISCO': 1,
#  'OSRIC': 1,
#  'REYNALDO': 1,
#  'Players': 2,
#  'A Gentleman': 0,
#  'A Priest': 0,
#  'Two Clowns': 0,
#  'A Captain': 0,
#  'English Ambassadors': 1,
#  'Lords, Ladies, Officers, Soldiers, Sailors, Messengers, and Attendants': 0}

# %%
connections
# Out:
# {('HAMLET', 'CLAUDIUS'): 0,
#  ('HAMLET', 'The GHOSTGERTRUDE'): 0,
#  ('HAMLET', 'POLONIUS'): 6,
#  ('HAMLET', 'LAERTES'): 4,
#  ('HAMLET', 'OPHELIA'): 2,
#  ('HAMLET', 'HORATIO'): 7,
#  ('HAMLET', 'FORTINBRAS'): 2,
#  ('HAMLET', 'VOLTEMAND'): 2,
#  ('HAMLET', 'CORNELIUS'): 1,
#  ('HAMLET', 'ROSENCRANTZ'): 7,
#  ('HAMLET', 'GUILDENSTERN'): 5,
#  ('HAMLET', 'MARCELLUS'): 3,
#  ('HAMLET', 'BARNARDO'): 1,
#  ('HAMLET', 'FRANCISCO'): 0,
#  ('HAMLET', 'OSRIC'): 1,
#  ('HAMLET', 'REYNALDO'): 0,
#  ('HAMLET', 'Players'): 2,
#  ('HAMLET', 'A Gentleman'): 0,
#  ('HAMLET', 'A Priest'): 0,
#  ('HAMLET', 'Two Clowns'): 0,
#  ('HAMLET', 'A Captain'): 0,
#  ('HAMLET', 'English Ambassadors'): 1,
#  ('HAMLET',
#   'Lords, Ladies, Officers, Soldiers, Sailors, Messengers, and Attendants'): 0,
#  ('CLAUDIUS', 'The GHOSTGERTRUDE'): 0,
#  ('CLAUDIUS', 'POLONIUS'): 0,
#  ('CLAUDIUS', 'LAERTES'): 0,
#  ('CLAUDIUS', 'OPHELIA'): 0,
#  ('CLAUDIUS', 'HORATIO'): 0,
#  ('CLAUDIUS', 'FORTINBRAS'): 0,
# ...

# %%
for k,v in charnum.items():
    print(k,v)
# Out:
# HAMLET 15
# CLAUDIUS 0
# The GHOSTGERTRUDE 0
# POLONIUS 8
# LAERTES 6
# OPHELIA 5
# HORATIO 8
# FORTINBRAS 2
# VOLTEMAND 2
# CORNELIUS 1
# ROSENCRANTZ 7
# GUILDENSTERN 5
# MARCELLUS 4
# BARNARDO 2
# FRANCISCO 1
# OSRIC 1
# REYNALDO 1
# Players 2
# A Gentleman 0
# A Priest 0
# Two Clowns 0
# A Captain 0
# English Ambassadors 1
# Lords, Ladies, Officers, Soldiers, Sailors, Messengers, and Attendants 0

# %%
graphitems = []

for k, v in charnum.items():
    dashnode = {'data' : {'id': k,
                         'label': k.title(),
                         'size': str(v)}}
    graphitems.append(dashnode)
    
graphitems
# Out:
# [{'data': {'id': 'HAMLET', 'label': 'Hamlet', 'size': '15'}},
#  {'data': {'id': 'CLAUDIUS', 'label': 'Claudius', 'size': '0'}},
#  {'data': {'id': 'The GHOSTGERTRUDE',
#    'label': 'The Ghostgertrude',
#    'size': '0'}},
#  {'data': {'id': 'POLONIUS', 'label': 'Polonius', 'size': '8'}},
#  {'data': {'id': 'LAERTES', 'label': 'Laertes', 'size': '6'}},
#  {'data': {'id': 'OPHELIA', 'label': 'Ophelia', 'size': '5'}},
#  {'data': {'id': 'HORATIO', 'label': 'Horatio', 'size': '8'}},
#  {'data': {'id': 'FORTINBRAS', 'label': 'Fortinbras', 'size': '2'}},
#  {'data': {'id': 'VOLTEMAND', 'label': 'Voltemand', 'size': '2'}},
#  {'data': {'id': 'CORNELIUS', 'label': 'Cornelius', 'size': '1'}},
#  {'data': {'id': 'ROSENCRANTZ', 'label': 'Rosencrantz', 'size': '7'}},
#  {'data': {'id': 'GUILDENSTERN', 'label': 'Guildenstern', 'size': '5'}},
#  {'data': {'id': 'MARCELLUS', 'label': 'Marcellus', 'size': '4'}},
#  {'data': {'id': 'BARNARDO', 'label': 'Barnardo', 'size': '2'}},
# ...

# %%
correction_factor = max(connections.values())
print(correction_factor)
for k,v in connections.items():
    if v != 0:
        dashedge = {'data': {'source': k[0],
                             'target': k[1],
                             'weight': v/correction_factor}}
        graphitems.append(dashedge)
# Out:
# 7

# %%
app = JupyterDash(__name__)

app.layout = html.Div([
    cyto.Cytoscape(
        layout={'name': 'cose'},
        elements=graphitems,
        style={'width': '100%', 'height': '750px'},
        stylesheet=[
            {
                'selector': 'node',
                'style': {
                    'content':'data(label)',
                    'text-halign':'center',
                    'text-valign':'center',
                    'width': 'data(size)',
                    'height': 'data(size)',
                    'font-size':4,
                    'color': 'black',
                    'background-color': 'red',
                    'text-outline-color': 'white',
                    'text-outline-width': 0.2,
                    'shape':'circle'
                }
            },
            {
                'selector':'edge',
                'style': {
                    'width':'data(weight)',
                    'line-color': 'blue',
                  }
            },
        ]
    )
])

app.run_server(debug=True)
# Out:
# Dash app running on https://jupyter.idre.ucla.edu/user/oregonduckmichael@hotmail.com/proxy/8050/

# %% [markdown]
# This graph is showing the connections and the interactions the characters had in the play. The bigger the character is, the most interactions they had. The most important node in this graph is Hamlet. As the main character, it is expected that he has the most interactions. You can see from the list that Hamlet has the most with the numerical value of 15 while others all have less than that. You can also see that edges that they are connected too have a certain thickness to them as this is meant to identify the most connection they had with this person.

# %%
graphitems
# Out:
# [{'data': {'id': 'HAMLET', 'label': 'Hamlet', 'size': '15'}},
#  {'data': {'id': 'CLAUDIUS', 'label': 'Claudius', 'size': '0'}},
#  {'data': {'id': 'The GHOSTGERTRUDE',
#    'label': 'The Ghostgertrude',
#    'size': '0'}},
#  {'data': {'id': 'POLONIUS', 'label': 'Polonius', 'size': '8'}},
#  {'data': {'id': 'LAERTES', 'label': 'Laertes', 'size': '6'}},
#  {'data': {'id': 'OPHELIA', 'label': 'Ophelia', 'size': '5'}},
#  {'data': {'id': 'HORATIO', 'label': 'Horatio', 'size': '8'}},
#  {'data': {'id': 'FORTINBRAS', 'label': 'Fortinbras', 'size': '2'}},
#  {'data': {'id': 'VOLTEMAND', 'label': 'Voltemand', 'size': '2'}},
#  {'data': {'id': 'CORNELIUS', 'label': 'Cornelius', 'size': '1'}},
#  {'data': {'id': 'ROSENCRANTZ', 'label': 'Rosencrantz', 'size': '7'}},
#  {'data': {'id': 'GUILDENSTERN', 'label': 'Guildenstern', 'size': '5'}},
#  {'data': {'id': 'MARCELLUS', 'label': 'Marcellus', 'size': '4'}},
#  {'data': {'id': 'BARNARDO', 'label': 'Barnardo', 'size': '2'}},
# ...

# %% [markdown]
# This grahitems code tells us the wieght of the connection between the characters. This is represented visually by the edges in the graph and we can see that the with Hamlet and Horatio. The weight is one of the heaviest and is displayed visually in the graph.
